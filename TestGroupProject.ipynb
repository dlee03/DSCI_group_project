# %%
library(tidyverse)
library(rvest)
# Out:
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.1 ──
#
# ✔ ggplot2 3.3.6     ✔ purrr   0.3.4
# ✔ tibble  3.1.7     ✔ dplyr   1.0.9
# ✔ tidyr   1.2.0     ✔ stringr 1.4.0
# ✔ readr   2.1.2     ✔ forcats 0.5.1
#
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
#
#
# Attaching package: ‘rvest’
#
#
# The following object is masked from ‘package:readr’:
#
#     guess_encoding

# %%
url <- "https://raw.githubusercontent.com/dlee03/DSCI_group_project/main/Pokemon.csv" 
pokemon2 <- read_csv(url)

pokemon2
# Out:
# Rows: 800 Columns: 13
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr (3): Name, Type 1, Type 2
# dbl (9): #, Total, HP, Attack, Defense, Sp. Atk, Sp. Def, Speed, Generation
# lgl (1): Legendary
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#     #   Name                      Type 1   Type 2 Total HP  Attack Defense
# 1    1  Bulbasaur                 Grass    Poison 318   45   49     49
# 2    2  Ivysaur                   Grass    Poison 405   60   62     63
# 3    3  Venusaur                  Grass    Poison 525   80   82     83
# 4    3  VenusaurMega Venusaur     Grass    Poison 625   80  100    123
# 5    4  Charmander                Fire     NA     309   39   52     43
# 6    5  Charmeleon                Fire     NA     405   58   64     58
# ...

# %%
#remove spaces in names and replace with '.'

colnames(pokemon2) <- make.names(colnames(pokemon2)) 
pokemon2
# Out:
#     X.  Name                      Type.1   Type.2 Total HP  Attack Defense
# 1    1  Bulbasaur                 Grass    Poison 318   45   49     49
# 2    2  Ivysaur                   Grass    Poison 405   60   62     63
# 3    3  Venusaur                  Grass    Poison 525   80   82     83
# 4    3  VenusaurMega Venusaur     Grass    Poison 625   80  100    123
# 5    4  Charmander                Fire     NA     309   39   52     43
# 6    5  Charmeleon                Fire     NA     405   58   64     58
# 7    6  Charizard                 Fire     Flying 534   78   84     78
# 8    6  CharizardMega Charizard X Fire     Dragon 634   78  130    111
# 9    6  CharizardMega Charizard Y Fire     Flying 634   78  104     78
# 10   7  Squirtle                  Water    NA     314   44   48     65
# 11   8  Wartortle                 Water    NA     405   59   63     80
# 12   9  Blastoise                 Water    NA     530   79   83    100
# ...

# %%
#summarize data that reports number of entries per column 

pokemon_selected <- pokemon2 |>
    select(Name, Attack, Defense, Sp..Atk, Sp..Def, Speed, Legendary)
pokemon_selected
# Out:
#     Name                      Attack Defense Sp..Atk Sp..Def Speed Legendary
# 1   Bulbasaur                  49     49      65      65      45   FALSE
# 2   Ivysaur                    62     63      80      80      60   FALSE
# 3   Venusaur                   82     83     100     100      80   FALSE
# 4   VenusaurMega Venusaur     100    123     122     120      80   FALSE
# 5   Charmander                 52     43      60      50      65   FALSE
# 6   Charmeleon                 64     58      80      65      80   FALSE
# 7   Charizard                  84     78     109      85     100   FALSE
# 8   CharizardMega Charizard X 130    111     130      85     100   FALSE
# 9   CharizardMega Charizard Y 104     78     159     115     100   FALSE
# 10  Squirtle                   48     65      50      64      43   FALSE
# 11  Wartortle                  63     80      65      80      58   FALSE
# 12  Blastoise                  83    100      85     105      78   FALSE
# ...

# %%
#find counts in each
pokemon_counts <- pokemon_selected |> 
    group_by() |>
    summarize(counts = n())
pokemon_counts
# Out:
#   counts
# 1 800

# %%
#convert the character variable to the factor datatype
mutate(Legendary = as_factor(Legendary))
# Out:
# Error in as_factor(Legendary): object 'Legendary' not found
# Traceback:
#
# 1. mutate(Legendary = as_factor(Legendary))
# 2. as_factor(Legendary)

# %%
#make training data set
pokemon_split <- initial_split(pokemon_selected, prop = 0.75, strata = Legendary)
pokemon_train <- training(pokemon_split)
pokemon_test <- testing(pokemon_split)
# Out:
# Error in initial_split(pokemon_selected, prop = 0.75, strata = Legendary): could not find function "initial_split"
# Traceback:

# %%
# create exploratory scatter plot 

options(repr.plot.width = 10, repr.plot.height =12) 
pokemon_plot1 <- pokemon_train |> 
    ggplot(aes(x= Attack , y= Defense )) +
    geom_point(aes(color = Legendary, shape = Legendary)) + 
    labs(x= " Attack ", y= "Defense ", color = "Legendary", shape = "Legendary") + 
    ggtitle ("Pokemon Attack and Defense Classified as Legendary") +
    theme(text = element_text(size =20)) 
pokemon_plot1
# Out:
# Error in options(cancer, repr.plot.width = 10, repr.plot.height = 12): object 'cancer' not found
# Traceback:
#
# 1. options(cancer, repr.plot.width = 10, repr.plot.height = 12)
